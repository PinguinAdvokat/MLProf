# %%
import os
import io
import gpxpy
import folium
import selenium
import requests
import numpy as np
import pandas as pd
import sqlite3 as sq
import seaborn as sb
import osmnx as ox
import matplotlib.pyplot as plt


from PIL import Image
from ipywidgets import IntProgress
from scipy.stats import normaltest, shapiro, kstest, f_oneway
from geopy.distance import geodesic
from IPython.display import display
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
def parse_gpx(gpx_string, track_id):
    try:
        gpx = gpxpy.parse(gpx_string)
    except Exception as e:
        print(e)
        return None
    points = []
    for track in gpx.tracks:
        for segment in track.segments:
            for point in segment.points:
                points.append({
                            'track_id': track_id,
                            'latitude': point.latitude,
                            'longitude': point.longitude,
                            'elevation': point.elevation,
                            'time': point.time,
                            'name': track.name
                        })
    return points

# %%
def length(parsed_gpx):
    length_3d = []
    for track in parsed_gpx.groupby('track_id'):
        track = track[1].sort_values('time')
        for idx in track.index[:-1]:
            p1 = (track['latitude'][idx], track['longitude'][idx])
            p2 = (track['latitude'][idx + 1], track['longitude'][idx + 1])
            length_2d = geodesic(p1, p2).meters
            if pd.notna(track['elevation'][idx]):
                length_track = np.sqrt((length_2d ** 2) + (track['elevation'][idx] - track['elevation'][idx + 1]) ** 2)
            else:
                length_track = length_2d
            length_3d.append(length_track)
        length_3d.append(None)
    return length_3d

# %%
def time_delta(parsed_gpx):
    time_delta = []
    for track in parsed_gpx.groupby('track_id'):
        track = track[1].sort_values('time')
        for idx in track.index[:-1]:
            time_delta.append(track['time'][idx + 1] - track['time'][idx])
        time_delta.append(None)
    return time_delta

# %%
def mean_day_temp(lat, lon, time):
    url = "https://archive-api.open-meteo.com/v1/archive"
    params = {
    	"latitude": lat,
    	"longitude": lon,
    	"start_date": time,
    	"end_date": time,
    	"daily": "temperature_2m_mean",
    }
    response = requests.get(url, params=params)
    return response.json()['daily']['temperature_2m_mean']

# %%
def temp_per_track(parsed_gpx):
    temp = {}
    for track in parsed_gpx.groupby('track_id'):
        track = track[1]
        if pd.notna(track['time']).sum():
            id = track.index[0]
            test = mean_day_temp(track['latitude'][id], track['longitude'][id], str(track['time'][id])[:10])
            temp[track['track_id'].mean()] = test[0]
        else:
            temp[track['track_id'].mean()] = None
    return temp

# %%
def parse_features(lat, lon, radius=500):
    point = (lat, lon)
    tags = {
        "water": {"natural": "water"},
        "forest": {"natural": "wood"},
        "buildings": {"building": True}
    }
    
    features = {}
    for key, tag in tags.items():
        try:
            gdf = ox.features.features_from_point(point, dist=radius, tags=tag)
            features[key] = len(gdf)
        except Exception as e:
            features[key] = 0
    
    return features

# %%
def get_features(parsed_gpx, n=3):
    bar = IntProgress(min=0, max=len(parsed_gpx.index))
    display(bar)
    water = []
    forest = []
    buildings = []
    features = parse_features(parsed_gpx['latitude'][0], parsed_gpx['longitude'][0])
    for idx in parsed_gpx.index:
        if idx % n == 0:
            features = parse_features(parsed_gpx['latitude'][idx], parsed_gpx['longitude'][idx])
        water.append(features['water'])
        forest.append(features['forest'])
        buildings.append(features['buildings'])
        bar.value += 1
        if idx == 50:
            break
    return water, forest, buildings

# %%
def around_type(df):
    if pd.notna(df[['water', 'forest', 'buildings']]).sum() and df[['water', 'forest', 'buildings' ]].sum():
        if df['water'] + df['forest'] > 0:
            around = {'water': df['water'], 'forest': df['forest']}
            return max(around, key=around.get)
        if df['buildings'] > 0:
            return 'city'
    return None

# %%
class Agent:
    def __init__(self, path_to_db:str, path_to_maps:str):
        self.path_to_db = path_to_db
        self.path_to_maps = path_to_maps
        ox.settings.use_cache=True

    def save_data(self):
        try:
            conn = sq.connect(self.path_to_db)
            self.data.to_sql("data", con=conn, if_exists="replace", index=False)
            conn.close()
        except Exception as e:
            print(e)

    def parse_paths(self, paths):
        all_points = []
        trace_id = []
        self.idx = 0
        for path in paths:
            gpx = open(path, 'r')
            parsed_gpx = parse_gpx(gpx, self.idx)
            if parsed_gpx:
                all_points.extend(parsed_gpx)
                self.idx += 1
        parsed_gpx = pd.DataFrame(all_points)
        print(f"Создан dataframe с {len(parsed_gpx['track_id'].unique())} маршрутами")
        self.data = parsed_gpx

    def add_gpx(self, gpx_strings:list[str]):
        all_points = []
        for gpx in gpx_strings:
            parsed_gpx = parse_gpx(gpx, self.idx)
            if parsed_gpx:
                all_points.extend(parsed_gpx)
                self.idx += 1
        parsed_gpx = pd.DataFrame(all_points)
        print(f"В датасет добавлены {len(parsed_gpx['track_id'].unique())} маршрутов")
        self.data = pd.concat([self.data, parsed_gpx], ignore_index=True)

    def fill_dataset(self):
        parsed_gpx = self.data
        
        length_3d = length(parsed_gpx)
        parsed_gpx['length_3d'] = length_3d
        print("Посчитанны расстояния между точками")
    
        parsed_gpx['time_delta'] = time_delta(parsed_gpx)
        print("Просчитано время между точками")
        parsed_gpx['step_frequency'] = parsed_gpx.apply(lambda parsed_gpx: (parsed_gpx['length_3d'] / 0.75) / (parsed_gpx['time_delta'].total_seconds() + 0.01), axis=1)
        print("Просчитана частота шагов")
    
        temp = temp_per_track(parsed_gpx)
        parsed_gpx['tempurture'] = parsed_gpx['track_id'].map(lambda x: temp[x])
        print("Просчитана температура для каждого трека")

        n=10
        water, forest, buildings = get_features(parsed_gpx, n=n)
        parsed_gpx['water'] = water + [None] * (len(parsed_gpx) - len(water))
        parsed_gpx['forest'] = forest + [None] * (len(parsed_gpx) - len(forest))
        parsed_gpx['buildings'] = buildings + [None] * (len(parsed_gpx) - len(buildings))
        parsed_gpx['type'] = parsed_gpx.apply(around_type, axis=1)
        print(f'Посчитано количество обьектов вокруг каждой {n} точки')
        
        self.data = parsed_gpx

    def gen_img(self):
        for track in self.data.groupby('track_id'):
            track = track[1]
            idx = track['track_id'].mean()
            m = folium.Map(location=[track['latitude'].mean(), track['longitude'].mean()], zoom_start=12)
            folium.PolyLine(track[['latitude', 'longitude']].values).add_to(m)
            print(f"Карта маршрута {idx}")
            display(m)
            img_data = m._to_png(5)
            img = Image.open(io.BytesIO(img_data))
            img.save(os.path.join(self.path_to_maps, f'{idx}.png'))

# %% [markdown]
# # Создаём агента и указываем ему пути для сохранения данных

# %%
agent = Agent("data.db", "Maps/")
agent.parse_paths(['datasets/1.gpx', 'datasets/2.gpx', 'datasets/3.gpx', 'datasets/4.gpx'])
# Out:
# Создан dataframe с 4 маршрутами

# %%
gpx_data = pd.read_csv("datasets/gpx-tracks-from-hikr.org.csv")

# %%
agent.add_gpx(list(gpx_data['gpx'][:30]))
# Out:
# В датасет добавлены 30 маршрутов

# %%
agent.data
# Out:
#       track_id   latitude  longitude  elevation                      time  \
# 0            0  46.988087   6.792303    1128.86                       NaT
# 1            0  46.988047   6.792166    1129.30                       NaT
# 2            0  46.989413   6.790911    1150.25                       NaT
# 3            0  46.990017   6.791000    1159.11                       NaT
# 4            0  46.990729   6.791723    1170.55                       NaT
# ...        ...        ...        ...        ...                       ...
# 5614        33  46.067089  11.167237     539.92 2018-04-29 14:31:29+00:00
# 5615        33  46.066518  11.166801     541.84 2018-04-29 14:32:11+00:00
# 5616        33  46.066596  11.165948     541.84 2018-04-29 14:32:43+00:00
# 5617        33  46.066146  11.166450     544.72 2018-04-29 14:33:13+00:00
# 5618        33  46.065987  11.166992     549.05 2018-04-29 14:34:35+00:00
#
#                                      name
# 0       La Tourne - Vue des Alp - Genevey
# 1       La Tourne - Vue des Alp - Genevey
# 2       La Tourne - Vue des Alp - Genevey
# 3       La Tourne - Vue des Alp - Genevey
# 4       La Tourne - Vue des Alp - Genevey
# ...                                   ...
# 5614  La Marzola (Sentiero Bertotti) 1942
# 5615  La Marzola (Sentiero Bertotti) 1942
# 5616  La Marzola (Sentiero Bertotti) 1942
# 5617  La Marzola (Sentiero Bertotti) 1942
# 5618  La Marzola (Sentiero Bertotti) 1942
#
# [5619 rows x 6 columns]

# %% [markdown]
# # Дополняем датасет необходимыми признаками

# %%
agent.fill_dataset()
# Out:
# Посчитанны расстояния между точками
# Просчитано время между точками
# Просчитана частота шагов
# Просчитана температура для каждого трека
# IntProgress(value=0, max=5619)
# Посчитано количество обьектов вокруг каждой 10 точки

# %% [markdown]
# # Создаём карты с наложеными маршрутами

# %%
agent.gen_img()
# Out:
# Карта маршрута 0.0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35bd25b70b345abdf72dd70c37b6de98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35bd25b70b345abdf72dd70c37b6de98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35bd25b70b345abdf72dd70c37b6de98 = L.map(
#                 &quot;map_35bd25b70b345abdf72dd70c37b6de98&quot;,
#                 {
#                     center: [47.03937124375814, 6.841120055938523],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18a7fe9471dce69595c18f6af4628d2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18a7fe9471dce69595c18f6af4628d2c.addTo(map_35bd25b70b345abdf72dd70c37b6de98);
#
#
#             var poly_line_ef84a7a7250dbbfffd3f87a75c24a49c = L.polyline(
47.220143, 13.222244], [47.220587, 13.222445], [47.220849, 13.222997], [47.220055, 13.225029], [47.220271, 13.225611], [47.219869, 13.227531], [47.219904, 13.22856], [47.220276, 13.22941], [47.2202, 13.230083], [47.219837, 13.230494], [47.220033, 13.230667], [47.220259, 13.230655], [47.220834, 13.230058], [47.220949, 13.229078], [47.221448, 13.228384], [47.221899, 13.22725], [47.223459, 13.225822], [47.223583, 13.225533], [47.223499, 13.224868], [47.224093, 13.225867], [47.224001, 13.227516], [47.224409, 13.227711], [47.224826, 13.22741], [47.224922, 13.227111], [47.22456, 13.229448], [47.226099, 13.228786], [47.226999, 13.227721], [47.227242, 13.227162], [47.227851, 13.226715], [47.228758, 13.226417], [47.229962, 13.224871], [47.23042, 13.224851], [47.230664, 13.225396], [47.230889, 13.225442], [47.230412, 13.227277], [47.230534, 13.227554], [47.23103, 13.226896]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_02c0966c9870e11fb4aa8fb3ca779a23);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
agent.save_data()
# Out:
# C:\Users\demoexam\AppData\Local\Temp\ipykernel_2452\935923383.py:10: UserWarning:
#
# the 'timedelta' type is not supported, and will be written as integer values (ns frequency) to the database.

# %%
agent.data.isnull().sum()
# Out:
# track_id             0
# latitude             0
# longitude            0
# elevation            0
# time               476
# name               593
# length_3d           34
# time_delta         506
# step_frequency     506
# tempurture         476
# water             5568
# forest            5568
# buildings         5568
# type              5568
# dtype: int64

# %%
agent.data
# Out:
#       track_id   latitude  longitude  elevation                      time  \
# 132          1  47.747739  11.484076     729.30 2018-04-29 06:10:21+00:00
# 133          1  47.746632  11.486308     738.43 2018-04-29 06:13:16+00:00
# 134          1  47.745676  11.487158     748.04 2018-04-29 06:14:46+00:00
# 135          1  47.745334  11.487705     752.85 2018-04-29 06:15:29+00:00
# 136          1  47.744620  11.488046     762.46 2018-04-29 06:16:45+00:00
# ...        ...        ...        ...        ...                       ...
# 5614        33  46.067089  11.167237     539.92 2018-04-29 14:31:29+00:00
# 5615        33  46.066518  11.166801     541.84 2018-04-29 14:32:11+00:00
# 5616        33  46.066596  11.165948     541.84 2018-04-29 14:32:43+00:00
# 5617        33  46.066146  11.166450     544.72 2018-04-29 14:33:13+00:00
# 5618        33  46.065987  11.166992     549.05 2018-04-29 14:34:35+00:00
#
#                                      name   length_3d      time_delta  \
# 132         ACTIVE LOG: 29 APR 2018 08:10  207.959856 0 days 00:02:55
# 133         ACTIVE LOG: 29 APR 2018 08:10  124.312739 0 days 00:01:30
# 134         ACTIVE LOG: 29 APR 2018 08:10   56.140379 0 days 00:00:43
# 135         ACTIVE LOG: 29 APR 2018 08:10   83.955299 0 days 00:01:16
# 136         ACTIVE LOG: 29 APR 2018 08:10   55.547081 0 days 00:00:50
# ...                                   ...         ...             ...
# 5614  La Marzola (Sentiero Bertotti) 1942   71.858042 0 days 00:00:42
# 5615  La Marzola (Sentiero Bertotti) 1942   66.529896 0 days 00:00:32
# 5616  La Marzola (Sentiero Bertotti) 1942   63.340265 0 days 00:00:30
# 5617  La Marzola (Sentiero Bertotti) 1942   45.651515 0 days 00:01:22
# 5618  La Marzola (Sentiero Bertotti) 1942         NaN             NaT
#
#       step_frequency  tempurture
# 132         1.584366        16.2
# 133         1.841466        16.2
# 134         1.740382        16.2
# 135         1.472706        16.2
# 136         1.480959        16.2
# ...              ...         ...
# 5614        2.280665        16.1
# 5615        2.771213        16.1
# 5616        2.814185        16.1
# 5617        0.742211        16.1
# 5618             NaN        16.1
#
# [4550 rows x 10 columns]

# %% [markdown]
# # Описания признаков получившегося датасета

# %%
describtions = pd.read_csv("describtions.csv")
describtions
# Out:
#           Название                  Перевод  \
# 0         latitude                   высота
# 1        longitude                   широта
# 2        elevation  высота над уровнем моря
# 3             time                    время
# 4             name                      имя
# 5        length_3d         длина трёхмерная
# 6       time_delta          разница времени
# 7   step_frequency            частота шагов
# 8       tempurture              температура
# 9            water                     вода
# 10          forest                      лес
# 11       buildings                постройки
# 12            type                      тип
#
#                                      Описание Тип данных Система счисления  \
# 0                            GPS высота точки      float           Градусы
# 1                            GPS широта точки      float           Градусы
# 2               высота точки над уровнем моря      float             метры
# 3                     время регистрации точки   TimeDate                 -
# 4                                имя маршрута        str                 -
# 5    расстояние между точками с учётом высоты      float             метры
# 6       время прохождения между двумя точками  TimeDelta                 -
# 7                               частота шагов      float                Гц
# 8   температура воздуха на момент прохождения      float           Градусы
# 9                             кол-во водоёмов        int                 -
# 10                               кол-во лесов        int                 -
# 11                            кол-во построек        int                 -
# 12                              тип местности        str                 -
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN

# %% [markdown]
# # Статистика

# %% [markdown]
# ## length_3d

# %%
sb.histplot(agent.data['length_3d'], kde=True)
# Out:
# <Axes: xlabel='length_3d', ylabel='Count'>

# %%
res = normaltest(agent.data['length_3d'])
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %%
res = shapiro(agent.data['length_3d'])
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %%
res = kstest(agent.data['length_3d'], 'expon')
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %% [markdown]
# ## time_delta

# %%
sb.histplot(agent.data['time_delta'].map(lambda x: x.seconds), kde=True)
# Out:
# <Axes: xlabel='time_delta', ylabel='Count'>

# %%
res = normaltest(agent.data['time_delta'].map(lambda x: x.seconds))
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %%
res = shapiro(agent.data['time_delta'].map(lambda x: x.seconds))
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %%
res = kstest(agent.data['time_delta'].map(lambda x: x.seconds), "expon")
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %% [markdown]
# ## tempurture

# %%
sb.histplot(agent.data['tempurture'], kde=True)
# Out:
# <Axes: xlabel='tempurture', ylabel='Count'>

# %%
res = normaltest(agent.data['tempurture'])
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %%
res = shapiro(agent.data['tempurture'])
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %% [markdown]
# ## step_frequency

# %%
sb.histplot(agent.data['step_frequency'], kde=True)
# Out:
# <Axes: xlabel='step_frequency', ylabel='Count'>

# %%
res = normaltest(agent.data['step_frequency'])
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %%
res = normaltest(agent.data['step_frequency'])
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %%
res = kstest(agent.data['step_frequency'], "expon")
print(res.statistic)
print(res.pvalue)
# Out:
# nan
# nan

# %% [markdown]
# ## type

# %%
sb.histplot(agent.data['type'], kde=True)
# Out:
# <Axes: xlabel='type', ylabel='Count'>

# %% [markdown]
# Создание числового датасета

# %%
clean = agent.data.drop(['name'], axis=1)
clean = clean.dropna()
#clean["type"] = clean["type"].map({'city': 0, 'water': 1, 'forest': 2})
clean['time_delta'] = clean['time_delta'].map(lambda x: x.seconds)
clean['time'] = clean['time'].map(lambda x: x.timestamp())

# %%
clean
# Out:
#       track_id   latitude  longitude  elevation          time   length_3d  \
# 132          1  47.747739  11.484076     729.30  1.524982e+09  207.959856
# 133          1  47.746632  11.486308     738.43  1.524982e+09  124.312739
# 134          1  47.745676  11.487158     748.04  1.524982e+09   56.140379
# 135          1  47.745334  11.487705     752.85  1.524983e+09   83.955299
# 136          1  47.744620  11.488046     762.46  1.524983e+09   55.547081
# ...        ...        ...        ...        ...           ...         ...
# 5613        33  46.067484  11.166993     542.80  1.525012e+09   47.876430
# 5614        33  46.067089  11.167237     539.92  1.525012e+09   71.858042
# 5615        33  46.066518  11.166801     541.84  1.525012e+09   66.529896
# 5616        33  46.066596  11.165948     541.84  1.525012e+09   63.340265
# 5617        33  46.066146  11.166450     544.72  1.525012e+09   45.651515
#
#       time_delta  step_frequency  tempurture
# 132          175        1.584366        16.2
# 133           90        1.841466        16.2
# 134           43        1.740382        16.2
# 135           76        1.472706        16.2
# 136           50        1.480959        16.2
# ...          ...             ...         ...
# 5613          56        1.139711        16.1
# 5614          42        2.280665        16.1
# 5615          32        2.771213        16.1
# 5616          30        2.814185        16.1
# 5617          82        0.742211        16.1
#
# [5113 rows x 9 columns]

# %%
res = normaltest(clean['type'])
print(res.statistic)
print(res.pvalue)
# Out:
# 69.12818222831062
# 9.750030115258255e-16

# %%
res = shapiro(clean['type'])
print(res.statistic)
print(res.pvalue)
# Out:
# 0.6947057619313242
# 6.565639032469043e-30

# %% [markdown]
# # Анализ значимых атрибутов

# %%
cor = clean.corr()
sb.heatmap(cor)
plt.show()

# %%
groups = [group['type'].values for name, group in clean.groupby('track_id')]
f_stat, p_val = f_oneway(*groups)
print(f_stat, p_val)
# Out:
# 148.32749751879754 1.0246838304828801e-69

# %%
groups = [group['latitude'].values for name, group in clean.groupby('track_id')]
f_stat, p_val = f_oneway(*groups)
print(f_stat, p_val)
# Out:
# 164159.15270707535 0.0

# %%
groups = [group['longitude'].values for name, group in clean.groupby('track_id')]
f_stat, p_val = f_oneway(*groups)
print(f_stat, p_val)
# Out:
# 2448440.794921188 0.0

# %%
groups = [group['time'].values for name, group in clean.groupby('track_id')]
f_stat, p_val = f_oneway(*groups)
print(f_stat, p_val)
# Out:
# 225883242.0809756 0.0

# %%
groups = [group['length_3d'].values for name, group in clean.groupby('track_id')]
f_stat, p_val = f_oneway(*groups)
print(f_stat, p_val)
# Out:
# 1.9330971772263497 0.12318518764388349

# %%
groups = [group['elevation'].values for name, group in clean.groupby('track_id')]
f_stat, p_val = f_oneway(*groups)
print(f_stat, p_val)
# Out:
# 480.8190861125838 1.6073235078811386e-150

# %%
groups = [group['forest'].values for name, group in clean.groupby('track_id')]
f_stat, p_val = f_oneway(*groups)
print(f_stat, p_val)
# Out:
# 48.24317085087762 1.440984623407166e-27

# %% [markdown]
# ### Анализ атрибутов показал, что признаки ('type', 'latitude', 'longitude', 'time', 'length_3d', 'elevation', 'forest') в датасете сильно влияют на схожесть групп

# %% [markdown]
# ## Проводим кластеризацию используя значимые атрибуты

# %%
pca = PCA(n_components=2)
class_data = clean[['latitude', 'longitude', 'time', 'length_3d', 'elevation']]
data_2d = pca.fit_transform(class_data)
dbscan = KMeans(n_clusters=3)
dbscan.fit(data_2d)
labels = dbscan.predict(data_2d)
plt.scatter(data_2d[:, 0], data_2d[:, 1], c=labels, cmap='viridis')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # Добавляем получившееся каластеры в датасет и сохраняем в БД

# %%
clean['cluster'] = labels

# %%
try:
    conn = sq.connect("data.db")
    clean.to_sql("clean", con=conn, if_exists="replace", index=False)
    conn.close()
except Exception as e:
    print(e)

# %% [markdown]
# # Подготовка датасета для dashbord

# %%
def get_season(date):
    month = date.month
    if month in [12, 1, 2]:
        return 0
    elif month in [3, 4, 5]:
        return 1
    elif month in [6, 7, 8]:
        return 2
    else:
        return 3

# %%
try:
    conn = sq.connect("data.db")
    df = pd.read_sql('SELECT * FROM data', conn)
    conn.close()
except Exception as e:
    print(e)

df['time'] = pd.to_datetime(df['time'])
df['season'] = df['time'].apply(get_season)
df['hour'] = df['time'].apply(lambda x: x.hour)

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd

app = Dash()

m = folium.Map(zoom_start=12)
for track in df.groupby('track_id'):
    track = track[1]
    folium.PolyLine(track[['latitude', 'longitude']].values).add_to(m)

map_html = m.get_root().render()

app.layout = [
    html.H1(children='I have no idea how it works', style={'textAlign':'center'}),
    dcc.Graph(figure=px.histogram(df, x='season', y='step_frequency', histfunc='avg')),
    dcc.Graph(figure=px.histogram(df, x='hour', y='tempurture', histfunc='avg')),
    dcc.Graph(figure=px.histogram(df, x='type', histfunc='count')),
    dcc.Graph(figure=px.histogram(df, x='elevation', y='step_frequency', histfunc='avg')),
    dcc.Graph(figure=px.histogram(df, x='tempurture', y='step_frequency', histfunc='avg')),
    html.Iframe(
        srcDoc=map_html,
        width="100%",
        height="600"
    )
]

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
